# %% [markdown]
# Assignment: Exp 8 — Reusable Modules, Packages & Built-in Modules

# %% [markdown]
# Name: Yash Kamble
# Class: TY C
# Roll No: C59

# %%
Module 1: calc_utils.py — add, sub, mul, div (import and use).
def add(a,b):
    return a+b

# %%
def sub(a,b):
    return a-b

# %%
def mul(a,b):
    return a*b

# %%
def div(a,b):
    return a/b if b!=0 else 'Inf'

# %%
# Example usage
print('Add 2+3 =', add(2,3))
print('Div 10/2 =', div(10,2))
Output:
Module 2: string_ops.py — count_vowels, reverse, is_palindrome.
def count_vowels(s):
    return sum(1 for ch in s.lower() if ch in 'aeiou')

# %%
def reverse(s):
    return s[::-1]

# %%
def is_palindrome(s):
    t=''.join(ch.lower() for ch in s if ch.isalnum())
    return t==t[::-1]

# %%
print('Vowels in hello:', count_vowels('hello'))
print('Reverse abc:', reverse('abc'))
print('Is Madam palindrome?', is_palindrome('Madam'))
Output:
Module 3: list_tools.py — largest, smallest, average.
def largest(lst):
    return max(lst)

# %%
def smallest(lst):
    return min(lst)

# %%
def average(lst):
    return sum(lst)/len(lst)

# %%
print('Largest:', largest([1,5,3]))
print('Avg:', average([1,5,3]))
Output:
Module 4: math_ops.py — factorial, sqrt, power.
import math

# %%
def factorial(n):
    return math.factorial(n)

# %%
def sqrt(n):
    return math.sqrt(n)

# %%
def power(x,y):
    return x**y

# %%
print('Fact 5:', factorial(5))
print('Sqrt 16:', sqrt(16))
Output:
Module 5: temperature.py — C<->F<->K conversions.
def c_to_f(c):
    return (c*9/5)+32

# %%
def f_to_c(f):
    return (f-32)*5/9

# %%
def c_to_k(c):
    return c+273.15

# %%
print('0C->F', c_to_f(0))
print('32F->C', f_to_c(32))
print('25C->K', c_to_k(25))
Output:
Module 6: finance.py — simple and compound interest.
def simple_interest(p,r,t):
    return (p*r*t)/100

# %%
def compound_interest(p,r,t):
    return p * ((1 + r/100)**t) - p

# %%
print('SI for 1000,5%,2yr:', simple_interest(1000,5,2))
print('CI for 1000,5%,2yr:', round(compound_interest(1000,5,2),2))
Output:
Module 7: geometry.py — area & perimeter for rectangle, triangle, circle.
import math

# %%
def rect_area(l,w): return l*w

# %%
def rect_perim(l,w): return 2*(l+w)

# %%
def tri_area(b,h): return 0.5*b*h

# %%
def circ_area(r): return math.pi*r*r

# %%
print('Rect area 3x4:', rect_area(3,4))
print('Circle area r=2:', round(circ_area(2),2))
Output:
Module 8: marks_utils.py — total, percentage, grade.
def total(marks):
    return sum(marks)

# %%
def percentage(marks):
    return sum(marks)/len(marks)

# %%
def grade(marks):
    p=percentage(marks)
    if p>=90: return 'A'
    if p>=75: return 'B'
    if p>=50: return 'C'
    return 'D'

# %%
marks=[80,85,90]
print('Total:', total(marks))
print('Percent:', percentage(marks))
print('Grade:', grade(marks))
Output:
Module 9: converter.py — cm->m, kg->g etc.
def cm_to_m(cm): return cm/100

# %%
def kg_to_g(kg): return kg*1000

# %%
print('200cm->m', cm_to_m(200))
print('2.5kg->g', kg_to_g(2.5))
Output:
Module 10: date_ops.py — days between two dates.
from datetime import date

# %%
def days_between(d1, d2):
    return abs((d2-d1).days)

# %%
print('Days between 2020-01-01 and 2020-01-10:', days_between(date(2020,1,1), date(2020,1,10)))
Output:
Module 11: string_compare.py — lexicographic comparison.
def compare(a,b):
    if a<b: return -1
    if a==b: return 0
    return 1

# %%
print('Compare a vs b:', compare('a','b'))
print('Compare abc vs abc:', compare('abc','abc'))
Output:
Module 12: number_utils.py — even, odd, prime, perfect.
def is_even(n): return n%2==0

# %%
def is_prime(n):
    if n<=1: return False
    i=2
    while i*i<=n:
        if n%i==0: return False
        i+=1
    return True

# %%
def is_perfect(n):
    return sum(i for i in range(1,n) if n%i==0)==n

# %%
print('2 even?', is_even(2))
print('7 prime?', is_prime(7))
print('6 perfect?', is_perfect(6))
Output:
Module 13: file_tools.py — count lines, words, chars in a text (use sample text).
text='Hello world\nThis is a test file\nLine3'
lines = text.splitlines()
words = text.split()
print('Lines:', len(lines))
print('Words:', len(words))
print('Chars:', len(text))
Output:
Module 14: matrix_utils.py — add, sub, transpose of 2D matrices.
def add(A,B):
    return [[A[i][j]+B[i][j] for j in range(len(A[0]))] for i in range(len(A))]

# %%
def transpose(A):
    return list(map(list, zip(*A)))

# %%
A=[[1,2],[3,4]]
B=[[5,6],[7,8]]
print('Add:', add(A,B))
print('Transpose A:', transpose(A))
Output:
Module 15: student_info.py — accept and display formatted details.
def display(name, roll, marks):
    print(f'Name: {name} | Roll: {roll} | Marks: {marks} | Total: {sum(marks)}')

# %%
display('Yash','C59',[80,85,90])
Output:
Package 1: mathpkg with add_sub and mul_div (use functions).
def add(a,b): return a+b

# %%
def sub(a,b): return a-b

# %%
def mul(a,b): return a*b

# %%
def div(a,b): return a/b if b else None

# %%
print('add_sub: 5+3=', add(5,3))
print('mul_div: 6*4=', mul(6,4))
Output:
Package 2: geometry pkg with area and perimeter modules (examples).
def area_rect(l,w): return l*w

# %%
def per_rect(l,w): return 2*(l+w)

# %%
print('Area 3x4:', area_rect(3,4))
print('Perim 3x4:', per_rect(3,4))
Output:
Package 3: student package marks & grade.
def total(marks): return sum(marks)

# %%
def percent(marks): return sum(marks)/len(marks)

# %%
def grade(p):
    if p>=90: return 'A'
    if p>=75: return 'B'
    return 'C'

# %%
m=[80,70,90]
print('Total:', total(m))
print('Percent:', percent(m))
print('Grade:', grade(percent(m)))
Output:
Package 4: bank package loan EMI and interest.
def emi(p,r,n):
    # r in percent per annum, monthly rate
    r_month = r/(12*100)
    return p * r_month * (1+r_month)**n / ((1+r_month)**n -1)

# %%
print('EMI approx:', round(emi(100000,7.5,12),2))
Output:
Package 5: stringpkg analysis & modify (vowel count, reverse).
def vowel_count(s): return sum(1 for ch in s.lower() if ch in 'aeiou')

# %%
def make_upper(s): return s.upper()

# %%
print('Vowels in hello:', vowel_count('hello'))
print('Upper:', make_upper('hi'))
Output:
Package 6: ecommerce package cart & billing (simple).
cart = []
def add_item(name,price): cart.append((name,price))
def bill():
    return sum(p for _,p in cart)

# %%
add_item('pen',10); add_item('book',120)
print('Cart total:', bill())
Output:
Package 7: filemanager with read & write (use temp file).
fname='/mnt/data/temp_file_exp8.txt'
with open(fname,'w') as f:
    f.write('hello world\nline2')
with open(fname) as f:
    print('File content lines:', f.read().splitlines())
Output:
Package 8: converter package temperature & distance (km<->miles).
def km_to_miles(km): return km*0.621371

# %%
def miles_to_km(mi): return mi/0.621371

# %%
print('10km->miles', round(km_to_miles(10),3))
Output:
Package 9: attendance package register & report (simple list).
register = []
def mark(name): register.append(name)
def report(): print('Present:', register)

# %%
mark('A'); mark('B'); report()
Output:
Package 10: games package dice and guess (dice roll).
import random

# %%
def dice(): return random.randint(1,6)

# %%
print('Dice roll:', dice())
Output:
Package 11: utilities list_utils & num_utils (max, prime).
def max_elem(lst): return max(lst)

# %%
def is_prime(n):
    if n<=1: return False
    i=2
    while i*i<=n:
        if n%i==0: return False
        i+=1
    return True

# %%
print('Max:', max_elem([1,5,3]))
print('7 prime?', is_prime(7))
Output:
Package 12: calendarpkg date_info & time_info (show date).
import datetime
print('Today:', datetime.date.today())
print('Now:', datetime.datetime.now().time())
Output:
Package 13: travel package fare & distance (simple).
def fare(dist, rate=10): return dist*rate

# %%
def distance(time, speed): return time*speed

# %%
print('Fare 5km:', fare(5))
print('Distance 2hr@40:', distance(2,40))
Output:
Package 14: shop package items & bill (prices dict).
items = {'pen':10,'book':120}
def add_item(name,price): items[name]=price
def total_cart(cart): return sum(items[i] for i in cart)
print('Total cart [pen,book]:', total_cart(['pen','book']))
Output:
Package 15: school package teacher & student modules (display).
def teacher(name,sub): print('Teacher:',name,'Subject:',sub)
def student(name,roll): print('Student:',name,'Roll:',roll)

# %%
teacher('T1','Math'); student('S1','C59')
Output:
Built-in 1: math module factorial, power, sqrt.
import math
print('fact 5:', math.factorial(5))
print('pow 2^3:', math.pow(2,3))
print('sqrt 16:', math.sqrt(16))
Output:
Built-in 2: math sin, cos, tan of 45 degrees.
import math
ang = math.radians(45)
print('sin45:', round(math.sin(ang),4))
print('cos45:', round(math.cos(ang),4))
print('tan45:', round(math.tan(ang),4))
Output:
Built-in 3: datetime current date and time.
import datetime
print('Now:', datetime.datetime.now())
Output:
Built-in 4: datetime calculate age from birthdate.
from datetime import date
birth = date(1995,5,15)
now = date.today()
age = now.year - birth.year - ((now.month, now.day) < (birth.month, birth.day))
print('Age:', age)
Output:
Built-in 5: random integers 1-100.
import random
print('Random ints:', [random.randint(1,100) for _ in range(5)])
Output:
Built-in 6: random simulate two dice.
import random
print('Dice1, Dice2:', random.randint(1,6), random.randint(1,6))
Output:
Built-in 7: os cwd and list files.
import os
print('CWD:', os.getcwd())
print('Files:', os.listdir('.')[:10])
Output:
Built-in 8: sys python version and argv.
import sys
print('Version:', sys.version.split()[0])
print('Argv sample length:', len(sys.argv))
Output:
Built-in 9: calendar print month calendar for Oct 2025.
import calendar
print(calendar.month(2025,10))
Output:
Built-in 10: statistics mean, median, mode.
import statistics
data=[1,2,2,3,4]
print('Mean:', statistics.mean(data))
print('Median:', statistics.median(data))
print('Mode:', statistics.mode(data))
Output:
Built-in 11: time measure loop execution time.
import time
start=time.time()
for i in range(100000): pass
end=time.time()
print('Elapsed (ms):', (end-start)*1000)
Output:
Built-in 12: platform system info.
import platform
print('Platform:', platform.system(), platform.release())
Output:
Built-in 13: json read/write sample.
import json
obj={'a':1,'b':2}
path='/mnt/data/exp8_sample.json'
with open(path,'w') as f: json.dump(obj,f)
with open(path) as f: print('Loaded:', json.load(f))
Output:
Built-in 14: csv read sample write and read back.
import csv
path='/mnt/data/exp8_sample.csv'
with open(path,'w',newline='') as f:
    w=csv.writer(f); w.writerow(['name','age']); w.writerow(['A',20])
with open(path) as f:
    r=csv.reader(f); print('Rows:', list(r))
Output:
Built-in 15: collections.Counter word frequency.
from collections import Counter
text='apple banana apple orange banana apple'
print(Counter(text.split()))
Output:
