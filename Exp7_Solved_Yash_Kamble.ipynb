# %% [markdown]
# Exp-7 : User-defined functions, Lambda functions, and Recursion

# %% [markdown]
# Name: Yash Kamble
# Class: TY C
# Roll No: C59

# %%
1. Write a user-defined function to find the largest of three numbers.
def largest(a, b, c):
    return max(a, b, c)

# %%
print('Input: 10,20,15')
print('Output:', largest(10,20,15))

# %%
Output:
2. Create a function to calculate the factorial of a given number.
def factorial(n):
    result = 1
    for i in range(2, n+1):
        result *= i
    return result

# %%
print('Input: 5')
print('Output:', factorial(5))

# %%
Output:
3. Define a function to check whether a given number is prime or not.
def is_prime(n):
    if n <= 1:
        return False
    i = 2
    while i * i <= n:
        if n % i == 0:
            return False
        i += 1
    return True

# %%
print('Input: 29')
print('Output:', is_prime(29))
print('Input: 30')
print('Output:', is_prime(30))

# %%
Output:
4. Write a function that takes a string as input and returns the number of vowels.
def count_vowels(s):
    return sum(1 for ch in s.lower() if ch in 'aeiou')

# %%
print("Input: 'Hello World'")
print('Output:', count_vowels('Hello World'))

# %%
Output:
5. Create a function that converts temperature from Celsius to Fahrenheit.
def c_to_f(c):
    return (c * 9/5) + 32

# %%
print('Input: 0°C')
print('Output:', c_to_f(0))

# %%
Output:
6. Define a function to find the sum of all even numbers in a list.
def sum_even(lst):
    return sum(x for x in lst if x % 2 == 0)

# %%
print('Input: [1,2,3,4,5,6]')
print('Output:', sum_even([1,2,3,4,5,6]))

# %%
Output:
7. Write a function that reverses a given string.
def reverse_string(s):
    return s[::-1]

# %%
print("Input: 'abc'")
print('Output:', reverse_string('abc'))

# %%
Output:
8. Create a function that checks whether a string is a palindrome.
def is_palindrome(s):
    s = ''.join(ch.lower() for ch in s if ch.isalnum())
    return s == s[::-1]

# %%
print("Input: 'Madam'")
print('Output:', is_palindrome('Madam'))

# %%
Output:
9. Define a function that returns the maximum and minimum values from a list.
def max_min(lst):
    return max(lst), min(lst)

# %%
print('Input: [3,1,4,2]')
print('Output:', max_min([3,1,4,2]))

# %%
Output:
10. Write a function to count the number of words in a sentence.
def word_count(sentence):
    return len(sentence.split())

# %%
print("Input: 'This is a sample sentence'")
print('Output:', word_count('This is a sample sentence'))

# %%
Output:
11. Create a function that accepts marks in 5 subjects and returns the percentage.
def percentage(marks):
    if not marks:
        return 0
    return sum(marks) / len(marks)

# %%
print('Input: [80,85,90,75,70]')
print('Output:', percentage([80,85,90,75,70]))

# %%
Output:
12. Define a function to calculate the area of a circle, rectangle, and triangle (use parameters).
import math
def area_circle(r):
    return math.pi * r * r

# %%
def area_rectangle(l, w):
    return l * w

# %%
def area_triangle(b, h):
    return 0.5 * b * h

# %%
print('Circle r=2 ->', area_circle(2))
print('Rectangle 3x4 ->', area_rectangle(3,4))
print('Triangle b=4 h=5 ->', area_triangle(4,5))

# %%
Output:
13. Write a function that takes a list and returns a new list with only unique elements.
def unique_list(lst):
    seen = []
    for x in lst:
        if x not in seen:
            seen.append(x)
    return seen

# %%
print('Input: [1,2,2,3,1]')
print('Output:', unique_list([1,2,2,3,1]))

# %%
Output:
14. Create a function that accepts a number and prints its multiplication table.
def table(n):
    for i in range(1, 11):
        print(f"{n} x {i} = {n*i}")

# %%
print('Input: 5')
print('Output:')
table(5)

# %%
Output:
15. Define a function that takes two lists and returns their element-wise sum.
def sum_two_lists(l1, l2):
    return [a + b for a, b in zip(l1, l2)]

# %%
print('Input: [1,2,3] and [4,5,6]')
print('Output:', sum_two_lists([1,2,3], [4,5,6]))

# %%
Output:
Lambda 1. Write a lambda function to add two numbers.
add = lambda a, b: a + b
print('Input: 2,3')
print('Output:', add(2,3))

# %%
Output:
Lambda 2. Create a lambda to find the square of a number.
square = lambda x: x**2
print('Input: 4')
print('Output:', square(4))

# %%
Output:
Lambda 3. Write a lambda that checks whether a number is even or odd.
even_odd = lambda n: 'Even' if n % 2 == 0 else 'Odd'
print('Input: 5')
print('Output:', even_odd(5))

# %%
Output:
Lambda 4. Use map() with lambda to double all elements in a list.
nums = [1,2,3,4]
doubled = list(map(lambda x: x*2, nums))
print('Input: [1,2,3,4]')
print('Output:', doubled)

# %%
Output:
Lambda 5. Use filter() with lambda to extract only even numbers from a list.
nums = [1,2,3,4,5,6]
evens = list(filter(lambda x: x%2==0, nums))
print('Input: [1,2,3,4,5,6]')
print('Output:', evens)

# %%
Output:
Lambda 6. Use reduce() (from functools) with lambda to find the product of all numbers in a list.
from functools import reduce
product = reduce(lambda x,y: x*y, [1,2,3,4])
print('Input: [1,2,3,4]')
print('Output:', product)

# %%
Output:
Lambda 7. Create a lambda that returns the maximum of two numbers.
maximum = lambda a, b: a if a > b else b
print('Input: 3,5')
print('Output:', maximum(3,5))

# %%
Output:
Lambda 8. Write a lambda to reverse a string.
reverse = lambda s: s[::-1]
print("Input: 'hello'")
print('Output:', reverse('hello'))

# %%
Output:
Lambda 9. Use a lambda to sort a list of tuples based on the second element.
tuples = [(1,3),(2,2),(3,1)]
sorted_by_second = sorted(tuples, key=lambda x: x[1])
print('Input: [(1,3),(2,2),(3,1)]')
print('Output:', sorted_by_second)

# %%
Output:
Lambda 10. Write a lambda function that converts all strings in a list to uppercase.
names = ['yash', 'kamble']
upper = list(map(lambda s: s.upper(), names))
print('Input: ["yash","kamble"]')
print('Output:', upper)

# %%
Output:
Lambda 11. Create a lambda to find the cube of a number.
cube = lambda n: n**3
print('Input: 3')
print('Output:', cube(3))

# %%
Output:
Lambda 12. Write a lambda to check whether a string starts with a vowel.
starts_vowel = lambda s: s[0].lower() in 'aeiou' if s else False
print("Input: 'Apple'")
print('Output:', starts_vowel('Apple'))

# %%
Output:
Lambda 13. Use map() and lambda to convert a list of temperatures from Celsius to Fahrenheit.
celsius = [0,10,20]
fahrenheit = list(map(lambda c: (c*9/5)+32, celsius))
print('Input: [0,10,20]')
print('Output:', fahrenheit)

# %%
Output:
Lambda 14. Use filter() and lambda to find names longer than 5 characters in a list.
names = ['yash', 'kamble', 'college']
long_names = list(filter(lambda n: len(n)>5, names))
print('Input:', names)
print('Output:', long_names)

# %%
Output:
Lambda 15. Use a lambda and map() to calculate the square root of numbers in a list.
import math
nums = [4,9,16]
sqrts = list(map(lambda x: math.sqrt(x), nums))
print('Input: [4,9,16]')
print('Output:', sqrts)

# %%
Output:
Recursion 1. Write a recursive function to calculate the factorial of a number.
def fact(n):
    return 1 if n == 0 else n * fact(n-1)

# %%
print('Input: 5')
print('Output:', fact(5))

# %%
Output:
Recursion 2. Write a recursive function to generate the Fibonacci series up to n terms.
def fib(n):
    if n <= 1:
        return n
    return fib(n-1) + fib(n-2)

# %%
print('Input: first 6 terms')
print([fib(i) for i in range(6)])

# %%
Output:
Recursion 3. Create a recursive function to find the sum of natural numbers up to n.
def sum_n(n):
    return 0 if n == 0 else n + sum_n(n-1)

# %%
print('Input: 5')
print('Output:', sum_n(5))

# %%
Output:
Recursion 4. Write a recursive function to reverse a string.
def rev(s):
    return '' if s == '' else s[-1] + rev(s[:-1])

# %%
print("Input: 'hello'")
print('Output:', rev('hello'))

# %%
Output:
Recursion 5. Write a recursive function to count the digits in a number.
def count_digits(n):
    n = abs(n)
    if n == 0:
        return 1
    return 1 + count_digits(n//10) if n > 0 else 0

# %%
print('Input: 12345')
print('Output:', count_digits(12345))

# %%
Output:
Recursion 6. Create a recursive function to calculate the power of a number (x^y).
def power(x, y):
    return 1 if y == 0 else x * power(x, y-1)

# %%
print('Input: 2^3')
print('Output:', power(2,3))

# %%
Output:
Recursion 7. Write a recursive function to find the greatest common divisor (GCD) of two numbers.
def gcd(a, b):
    return a if b == 0 else gcd(b, a % b)

# %%
print('Input: 48,18')
print('Output:', gcd(48,18))

# %%
Output:
Recursion 8. Create a recursive function to check whether a number is palindrome or not.
def is_palindrome_recursive(s):
    s = ''.join(ch.lower() for ch in s if ch.isalnum())
    if len(s) <= 1:
        return True
    return s[0] == s[-1] and is_palindrome_recursive(s[1:-1])

# %%
print("Input: 'madam'")
print('Output:', is_palindrome_recursive('madam'))

# %%
Output:
Recursion 9. Write a recursive function to find the sum of elements in a list.
def sum_list(lst):
    return 0 if not lst else lst[0] + sum_list(lst[1:])

# %%
print('Input: [1,2,3,4]')
print('Output:', sum_list([1,2,3,4]))

# %%
Output:
Recursion 10. Write a recursive function to print all elements of a list in reverse order.
def rev_list_print(lst):
    if not lst:
        return
    rev_list_print(lst[1:])
    print(lst[0])

# %%
print('Input: [1,2,3]')
rev_list_print([1,2,3])

# %%
Output:
Recursion 11. Create a recursive function to find the length of a string.
def str_len(s):
    return 0 if s == '' else 1 + str_len(s[1:])

# %%
print("Input: 'hello'")
print('Output:', str_len('hello'))

# %%
Output:
Recursion 12. Write a recursive function to convert a decimal number to binary.
def dec_to_bin(n):
    if n == 0:
        return '0'
    if n == 1:
        return '1'
    return dec_to_bin(n // 2).lstrip('0') + str(n % 2)

# %%
print('Input: 10')
print('Output:', dec_to_bin(10))

# %%
Output:
Recursion 13. Create a recursive function to find the minimum element in a list.
def min_list(lst):
    if len(lst) == 1:
        return lst[0]
    sub_min = min_list(lst[1:])
    return lst[0] if lst[0] < sub_min else sub_min

# %%
print('Input: [3,1,4,2]')
print('Output:', min_list([3,1,4,2]))

# %%
Output:
Recursion 14. Write a recursive function to compute the sum of digits of a number.
def sum_digits(n):
    n = abs(n)
    return 0 if n == 0 else n % 10 + sum_digits(n // 10)

# %%
print('Input: 1234')
print('Output:', sum_digits(1234))

# %%
Output:
Recursion 15. Create a recursive function to check whether a given string is palindrome.
def is_palindrome_str(s):
    s = ''.join(ch.lower() for ch in s if ch.isalnum())
    if len(s) <= 1:
        return True
    return s[0] == s[-1] and is_palindrome_str(s[1:-1])

# %%
s = 'Able was I ere I saw Elba'
print(f"Input: '{s}'")
print('Output:', is_palindrome_str(s))

# %% [markdown]
# Output:
